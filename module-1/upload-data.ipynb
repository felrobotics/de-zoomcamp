# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.0'

# %%
# !ls
# Out:
# docker-compose.yml    output.csv	     test.sql
# Dockerfile	      output.csv.gz	     upload-data.ipynb
# ingest_data_green.py  taxi+_zone_lookup.csv  yellow_head.csv
# ingest_data.py	      terraform		     yellow_tripdata_2021-01.csv

# %%
df = pd.read_csv('green_tripdata_2019-09.csv.gz', nrows=5)

# %%
df
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2019-09-01 00:10:53   2019-09-01 00:23:46                  N
# 1         2  2019-09-01 00:31:22   2019-09-01 00:44:37                  N
# 2         2  2019-09-01 00:50:24   2019-09-01 01:03:20                  N
# 3         2  2019-09-01 00:27:06   2019-09-01 00:33:22                  N
# 4         2  2019-09-01 00:43:23   2019-09-01 00:59:54                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0           1            65           189                5           2.00
# 1           1            97           225                5           3.20
# 2           1            37            61                5           2.99
# 3           1           145           112                1           1.73
# 4           1           112           198                1           3.42
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# ...

# %%
df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine("postgresql://root:root@localhost:5433/ny_taxi")

# %%
engine.connect()

# %%
print(pd.io.sql.get_schema(df, name="green_taxi_data",con=engine))
# Out:
# CREATE TABLE green_taxi_data (
# 	"VendorID" BIGINT,
# 	lpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	lpep_dropoff_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	store_and_fwd_flag TEXT,
# 	"RatecodeID" BIGINT,
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	passenger_count BIGINT,
# 	trip_distance FLOAT(53),
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	ehail_fee FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	payment_type BIGINT,
# 	trip_type BIGINT,
# 	congestion_surcharge FLOAT(53)
# )

# %%
df_iter = pd.read_csv('green_tripdata_2019-09.csv.gz', iterator=True, chunksize=5000)

# %%
df_iter

# %%
df = next(df_iter)

# %%
df
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0             2  2019-09-01 00:10:53   2019-09-01 00:23:46                  N
# 1             2  2019-09-01 00:31:22   2019-09-01 00:44:37                  N
# 2             2  2019-09-01 00:50:24   2019-09-01 01:03:20                  N
# 3             2  2019-09-01 00:27:06   2019-09-01 00:33:22                  N
# 4             2  2019-09-01 00:43:23   2019-09-01 00:59:54                  N
# ...         ...                  ...                   ...                ...
# 99995         2  2019-09-08 21:34:31   2019-09-08 21:42:44                  N
# 99996         2  2019-09-08 21:06:54   2019-09-08 21:12:38                  N
# 99997         2  2019-09-08 21:22:10   2019-09-08 21:29:33                  N
# 99998         2  2019-09-08 21:33:42   2019-09-08 21:33:48                  N
# 99999         2  2019-09-08 21:29:16   2019-09-08 21:36:45                  N
#
# ...

# %%
df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [VendorID, tpep_pickup_datetime, tpep_dropoff_datetime, passenger_count, trip_distance, RatecodeID, store_and_fwd_flag, PULocationID, DOLocationID, payment_type, fare_amount, extra, mta_tax, tip_amount, tolls_amount, improvement_surcharge, total_amount, congestion_surcharge]
# Index: []

# %%
df.head(0).to_sql(name="yellow_taxi_data", con=engine, if_exists="replace")
# Out:
# 0

# %%
# %time df.to_sql(name="yellow_taxi_data", con=engine, if_exists="append")
# Out:
# CPU times: user 7.1 s, sys: 61 ms, total: 7.16 s
# Wall time: 11.1 s
# 1000

# %%
from time import time

# %%
from time import time
df.head(0).to_sql(name="green_taxi_data", con=engine, if_exists="replace")
df_iter = pd.read_csv('green_tripdata_2019-09.csv.gz', iterator=True, chunksize=5, low_memory=False)
while True:
    print("New chunck")
    t_start = time()
    df = next(df_iter)
    df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
    df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
    print(df)
    df.to_sql(name="green_taxi_data", con=engine, if_exists="append")
    t_end = time()
    print(f"Inserted another chunck..., took {t_end-t_start:.3f} seconds")
# Out:
# New chunck
# Inserted another chunck..., took 0.991 seconds
# New chunck
# Inserted another chunck..., took 0.973 seconds
# New chunck
# Inserted another chunck..., took 1.008 seconds
# New chunck
# Inserted another chunck..., took 1.371 seconds
# New chunck
# Inserted another chunck..., took 0.996 seconds
# New chunck
# Inserted another chunck..., took 1.007 seconds
# New chunck
# Inserted another chunck..., took 0.971 seconds
# New chunck
# Inserted another chunck..., took 0.998 seconds
# New chunck
# Inserted another chunck..., took 1.035 seconds
# New chunck
# Inserted another chunck..., took 1.140 seconds
# New chunck
# Inserted another chunck..., took 1.026 seconds
# New chunck
# Inserted another chunck..., took 0.994 seconds
# New chunck
# Inserted another chunck..., took 0.970 seconds
# New chunck
# Inserted another chunck..., took 0.967 seconds
# New chunck
# Inserted another chunck..., took 0.966 seconds
# New chunck
# Inserted another chunck..., took 1.003 seconds
# ...
